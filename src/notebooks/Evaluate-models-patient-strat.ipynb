# %% [markdown]
# 1.[Cross-validation](#cv) <br>
# 2.[QTDB](#qt) <br>
# 3.[LUDB](#lu) <br>
# 4.[PTB](#ptb) <br>

# %% [markdown]
# <a id="cv"></a>
# ## Cross-validation

# %%
from compare_models import evaluate_cv, evaluate_delineator_private
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-8610ef58cc78> in <module>
# ----> 1 from compare_models import evaluate_cv, evaluate_delineator_private
#
# /project-ecg/compare_models.py in <module>
#      42
#      43 nfold = 5
# ---> 44 models_cnn = [load_model('experiments/cnn_stratified', fold=fold)  for fold in range(nfold)]
#      45 models_resnet = [load_model('experiments/resnet_no_ptb', fold=fold)  for fold in range(nfold)]
#      46 models_unet = [load_model('experiments/unet_no_ptb', fold=fold)  for fold in range(nfold)]
#
# /project-ecg/compare_models.py in <listcomp>(.0)
#      42
#      43 nfold = 5
# ---> 44 models_cnn = [load_model('experiments/cnn_stratified', fold=fold)  for fold in range(nfold)]
#      45 models_resnet = [load_model('experiments/resnet_no_ptb', fold=fold)  for fold in range(nfold)]
# ...

# %%
global_refs, global_preds, global_dices = evaluate_cv('experiments/cnn_stratified')
# Out:
# Evaluating 12 leads
#
# Fold 1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-e6b556033d43> in <module>
# ----> 1 global_refs, global_preds, global_dices = evaluate_cv('experiments/cnn_stratified')
#
# /project-ecg/compare_models.py in evaluate_cv(model_dir, show)
#      61
#      62          # Define the model
# ---> 63         model, loss_fn, params = load_model(model_dir, fold = fold, add_loss_fn = True)
#      64
#      65         # Sample elements randomly from a given list of ids, no replacement.
#
# /project-ecg/compare_models.py in load_model(model_dir, fold, add_loss_fn)
#      34
#      35     model, loss_fn = choose_model(model_dir, params)
# ---> 36     utils.load_checkpoint(os.path.join(model_dir, 'best' + '-{}.pth.tar'.format(fold+1)), model)
#      37     model.eval()
#      38     if add_loss_fn:
#
# ...

# %% [markdown]
# <a id="qt"></a>
# ## QTDB

# %%
from compare_models import evaluate_model

# %%
evaluate_model(model= 'cnn', db_name='qt')
# Out:
# 100%|████████████████████████████████████████| 206/206 [15:12<00:00,  4.43s/it, MAE=66.8648 ± 63.3228]

# %% [markdown]
# <a id="lu"></a>
# ## LUDB

# %%
evaluate_model(model= 'cnn', db_name='lu')
# Out:
# 100%|██████████████████████████████████████| 2391/2391 [37:00<00:00,  1.08it/s, MAE=38.7222 ± 30.6097]

# %% [markdown]
# <a id="ptb"></a>
# ## PTB

# %%
from compare_models import evaluate_model_bis

# %%
evaluate_model_bis(model= 'cnn', db_name='ptb')
# Out:
#   1%|▍                                     | 94/8235 [02:25<3:30:13,  1.55s/it, MAE=24.7309 ± 27.1714]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-0bfb02940a05> in <module>
# ----> 1 evaluate_model_bis(model= 'cnn', db_name='ptb')
#
# /project-ecg/compare_models.py in evaluate_model_bis(db_name, model, show)
#     201     with tqdm(total=len(data)) as pbar:
#     202         for record in data.records:
# --> 203             for lead in data.leads:
#     204                 summary = data[record, lead]
#     205                 if summary:
#
# /project-ecg/compare_models.py in __getitem__(self, args)
#     347         qt_ref = self.reference.loc[record_name]['qt']
#     348
# --> 349         sig = signals[lead][:30*fs]
#     350         final_rpeaks, rpeaks, _, _ = get_final_rpeaks(sig, sampling_rate = self.sampling_rate)
# ...
